# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - id - Идентификатор записи
# - Temparature - Температура
# - Humidity - Влажность
# - Moisture - Увлажнение
# - Soil Type - Тип почвы
# - Crop Type - Тип культуры
# - Nitrogen - Азот
# - Potassium - Калий
# - Phosphorous - Фосфор

# %%
data = pd.read_csv('../../data/raw/train.csv')
data.columns = data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               750000 non-null  int64
#  1   temparature      750000 non-null  int64
#  2   humidity         750000 non-null  int64
#  3   moisture         750000 non-null  int64
#  4   soil type        750000 non-null  object
#  5   crop type        750000 non-null  object
#  6   nitrogen         750000 non-null  int64
#  7   potassium        750000 non-null  int64
#  8   phosphorous      750000 non-null  int64
#  9   fertilizer name  750000 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 57.2+ MB

# %% [markdown]
# ## Temparature

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data.temparature.value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# ## Humidity

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data.humidity.value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# # Moisture

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data.moisture.value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# # Soil Type

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data['soil type'].value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# ## Crop Type

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data['crop type'].value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# ## Nitrogen

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data.nitrogen.value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# ## Potassium

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data.potassium.value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# ## Phosphorous

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data.phosphorous.value_counts(),
            color='skyblue')
plt.show()

# %% [markdown]
# ## Fertilizer Name

# %%
plt.figure(figsize=(20, 5))
sns.barplot(data['fertilizer name'].value_counts(),
            color='skyblue')
plt.title()
plt.show()
